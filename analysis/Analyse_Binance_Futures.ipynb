# %% [markdown]
# <h1>Analyse cryptos Futures sur Binance</h1>
# SEG

# %%
import sys
sys.path.append('../')
from utilities.data_manager import ExchangeDataManager
import pandas as pd

# %% [markdown]
# <h2>Liste de toutes les paires Futures sur Bitget</h2>

# %%
import requests

url = "https://fapi.binance.com/fapi/v1/exchangeInfo"

response = requests.get(url)
data = response.json()

if response.status_code == 200:
    # Extraction des noms des cryptomonnaies au format "BTC/USDT:USDT"
    futures_cryptos = [symbol['symbol'] for symbol in data['symbols']]
    formatted_cryptos = [f"{crypto[:-4]}/USDT:USDT" for crypto in futures_cryptos]
    print(f"Cryptomonnaies disponibles en futures sur Binance: {len(formatted_cryptos)}")
    print(formatted_cryptos)
else:
    print(f"Erreur lors de la requête : {response.status_code}")
# Out:
# Cryptomonnaies disponibles en futures sur Binance: 283
# ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'BCH/USDT:USDT', 'XRP/USDT:USDT', 'EOS/USDT:USDT', 'LTC/USDT:USDT', 'TRX/USDT:USDT', 'ETC/USDT:USDT', 'LINK/USDT:USDT', 'XLM/USDT:USDT', 'ADA/USDT:USDT', 'XMR/USDT:USDT', 'DASH/USDT:USDT', 'ZEC/USDT:USDT', 'XTZ/USDT:USDT', 'BNB/USDT:USDT', 'ATOM/USDT:USDT', 'ONT/USDT:USDT', 'IOTA/USDT:USDT', 'BAT/USDT:USDT', 'VET/USDT:USDT', 'NEO/USDT:USDT', 'QTUM/USDT:USDT', 'IOST/USDT:USDT', 'THETA/USDT:USDT', 'ALGO/USDT:USDT', 'ZIL/USDT:USDT', 'KNC/USDT:USDT', 'ZRX/USDT:USDT', 'COMP/USDT:USDT', 'OMG/USDT:USDT', 'DOGE/USDT:USDT', 'SXP/USDT:USDT', 'KAVA/USDT:USDT', 'BAND/USDT:USDT', 'RLC/USDT:USDT', 'WAVES/USDT:USDT', 'MKR/USDT:USDT', 'SNX/USDT:USDT', 'DOT/USDT:USDT', 'DEFI/USDT:USDT', 'YFI/USDT:USDT', 'BAL/USDT:USDT', 'CRV/USDT:USDT', 'TRB/USDT:USDT', 'RUNE/USDT:USDT', 'SUSHI/USDT:USDT', 'SRM/USDT:USDT', 'EGLD/USDT:USDT', 'SOL/USDT:USDT', 'ICX/USDT:USDT', 'STORJ/USDT:USDT', 'BLZ/USDT:USDT', 'UNI/USDT:USDT', 'AVAX/USDT:USDT', 'FTM/USDT:USDT', 'HNT/USDT:USDT', 'ENJ/USDT:USDT', 'FLM/USDT:USDT', 'TOMO/USDT:USDT', 'REN/USDT:USDT', 'KSM/USDT:USDT', 'NEAR/USDT:USDT', 'AAVE/USDT:USDT', 'FIL/USDT:USDT', 'RSR/USDT:USDT', 'LRC/USDT:USDT', 'MATIC/USDT:USDT', 'OCEAN/USDT:USDT', 'CVC/USDT:USDT', 'BEL/USDT:USDT', 'CTK/USDT:USDT', 'AXS/USDT:USDT', 'ALPHA/USDT:USDT', 'ZEN
T', 'ARB/USDT:USDT', 'JOE/USDT:USDT', 'TLM/USDT:USDT', 'AMB/USDT:USDT', 'LEVER/USDT:USDT', 'RDNT/USDT:USDT', 'HFT/USDT:USDT', 'XVS/USDT:USDT', 'ET/USDT:USDT', 'BLUR/USDT:USDT', 'EDU/USDT:USDT', 'IDEX/USDT:USDT', 'SUI/USDT:USDT', '1000PEPE/USDT:USDT', '1000FLOKI/USDT:USDT', 'UMA/USDT:USDT', 'RAD/USDT:USDT', 'KEY/USDT:USDT', 'COMBO/USDT:USDT', 'NMR/USDT:USDT', 'MAV/USDT:USDT', 'MDT/USDT:USDT', 'XVG/USDT:USDT', 'WLD/USDT:USDT', 'PENDLE/USDT:USDT', 'ARKM/USDT:USDT', 'AGLD/USDT:USDT', 'YGG/USDT:USDT', 'DODOX/USDT:USDT', 'BNT/USDT:USDT', 'OXT/USDT:USDT', 'SEI/USDT:USDT', 'CYBER/USDT:USDT', 'HIFI/USDT:USDT', 'ARK/USDT:USDT', 'FRONT/USDT:USDT', 'GLMR/USDT:USDT', 'BICO/USDT:USDT', 'BTCUSDT_24/USDT:USDT', 'ETHUSDT_24/USDT:USDT', 'STRAX/USDT:USDT', 'LOOM/USDT:USDT', 'BIGTIME/USDT:USDT', 'BOND/USDT:USDT', 'ORBS/USDT:USDT', 'STPT/USDT:USDT', 'WAXP/USDT:USDT', 'BSV/USDT:USDT', 'RIF/USDT:USDT', 'POLYX/USDT ...

# %% [markdown]
# <h2>Téléchargement de toutes les paires sur Binance</h2>

# %%
exchange_name = "binance"
intervals = ["1h"]

exchange = ExchangeDataManager(exchange_name=exchange_name, path_download="../database/exchanges")
await exchange.download_data(coins=formatted_cryptos, intervals=intervals,)
# Out:
# 	Récupération pour la paire BTC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ETH/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BCH/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire XRP/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire EOS/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire LTC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire TRX/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ETC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire LINK/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire XLM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ADA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire XMR/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DASH/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ZEC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire XTZ/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BNB/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ATOM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ONT/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire IOTA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BAT/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire VET/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire NEO/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire QTUM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire IOST/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire THETA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ALGO/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ZIL/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire KNC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ZRX/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire COMP/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire OMG/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DOGE/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SXP/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire KAVA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BAND/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire RLC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire WAVES/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire MKR/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SNX/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DOT/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DEFI/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire YFI/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BAL/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire CRV/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire TRB/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire RUNE/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SUSHI/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SRM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire EGLD/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SOL/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ICX/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire STORJ/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BLZ/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire UNI/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire AVAX/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire FTM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire HNT/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ENJ/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire FLM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire TOMO/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire REN/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire KSM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire NEAR/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire AAVE/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire FIL/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire RSR/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire LRC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire MATIC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire OCEAN/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire CVC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BEL/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire CTK/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire AXS/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ALPHA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ZEN/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SKL/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire GRT/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire 1INCH/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire CHZ/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SAND/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ANKR/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BTS/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire LIT/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire UNFI/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire REEF/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire RVN/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SFP/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire XEM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BTCST/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire COTI/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire CHR/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire MANA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ALICE/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire HBAR/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ONE/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire LINA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire STMX/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DENT/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire CELR/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire HOT/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire MTL/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire OGN/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire NKN/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DGB/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire 1000SHIB/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BAKE/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire GTC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire BTCDOM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire IOTX/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire AUDIO/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire RAY/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire C98/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire MASK/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ATA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DYDX/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire 1000XEC/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire GALA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire CELO/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire AR/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire KLAY/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire
200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1692025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1695625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1699225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1702825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1706425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# 	Pas de données pour ETHUSDT_24/USDT:USDT en 1h sur cette période
# 	Récupération pour la paire STRAX/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# ...
# Error during download BTCUSDT_24/USDT:USDT 1h 1544425200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1548025200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1551625200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1555225200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1558825200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1562425200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1566025200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1569625200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1573225200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1576825200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1580425200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1584025200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1587625200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1591225200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1594825200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1598425200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1602025200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1605625200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1609225200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1612825200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1616425200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1620025200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1623625200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1627225200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1630825200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1634425200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1638025200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1641625200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1645225200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1648825200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1652425200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1656025200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1659625200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1663225200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1666825200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1670425200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1674025200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1677625200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1681225200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1684825200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1688425200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1692025200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1695625200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1699225200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1702825200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# Error during download BTCUSDT_24/USDT:USDT 1h 1706425200000 binance does not have market symbol BTCUSDT_24/USDT:USDT
# 	Pas de données pour BTCUSDT_24/USDT:USDT en 1h sur cette période
# 	Récupération pour la paire ETHUSDT_24/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/63 [00:00<?, ?it/s]
# Error during download ETHUSDT_24/USDT:USDT 1h 1483225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1486825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1490425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1494025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1497625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1501225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1504825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1508425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1512025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1515625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1519225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1522825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1526425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1530025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1533625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1537225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1540825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1544425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1548025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1551625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1555225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1558825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1562425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1566025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1569625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1573225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1576825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1580425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1584025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1587625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1591225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1594825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1598425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1602025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1605625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1609225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1612825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1616425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1620025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1623625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1627225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1630825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1634425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1638025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1641625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1645225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1648825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1652425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1656025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1659625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1663225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1666825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1670425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1674025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1677625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1681225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1684825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1688425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1692025200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1695625200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1699225200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1702825200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# Error during download ETHUSDT_24/USDT:USDT 1h 1706425200000 binance does not have market symbol ETHUSDT_24/USDT:USDT
# 	Pas de données pour ETHUSDT_24/USDT:USDT en 1h sur cette période
# 	Récupération pour la paire BTC/USDT:USDT en timeframe 1h sur l'exchange binance...
# 	Données déjà récupérées
# 	Récupération pour la paire ETH/USDT:USDT en timeframe 1h sur l'exchange binance...
# 	Données déjà récupérées
# 	Récupération pour la paire BNB/USDT:USDT en timeframe 1h sur l'exchange binance...
# 	Données déjà récupérées
# 	Récupération pour la paire SOL/USDT:USDT en timeframe 1h sur l'exchange binance...
# 	Données déjà récupérées
# 	Récupération pour la paire XRP/USDT:USDT en timeframe 1h sur l'exchange binance...
# 	Données déjà récupérées
# 	Récupération pour la paire AI/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire XAI/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DOGE/USDT:USDT en timeframe 1h sur l'exchange binance...
# 	Données déjà récupérées
# 	Récupération pour la paire WIF/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire MANTA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ONDO/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire LSK/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ALT/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire JUP/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire ZETA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire RONIN/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire DYM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire SUI/USDT:USDT en timeframe 1h sur l'exchange binance...
# 	Données déjà récupérées
# 	Récupération pour la paire OM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/1 [00:00<?, ?it/s]
# 	Récupération pour la paire LINK/USDT:USDT en timeframe 1h sur l'exchange binance...
# 	Données déjà récupérées
# 	Récupération pour la paire PIXEL/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/63 [00:00<?, ?it/s]
# 	Récupération pour la paire STRK/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/63 [00:00<?, ?it/s]
# 	Récupération pour la paire MAVIA/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/63 [00:00<?, ?it/s]
# 	Récupération pour la paire ORDI/USDT:USDT en timeframe 1h sur l'exchange binance...
# 	Données déjà récupérées
# 	Récupération pour la paire GLM/USDT:USDT en timeframe 1h sur l'exchange binance...
#   0%|          | 0/63 [00:00<?, ?it/s]

# %% [markdown]
# Chargement des données

# %%
pair_list = formatted_cryptos
exchange_name = "binance"
tf = '1h'
oldest_pair = "BTC/USDT:USDT"
start_date = "2020-06"

exchange = ExchangeDataManager(
    exchange_name=exchange_name, 
    path_download="../database/exchanges"
)

df_list = {}
for pair in pair_list:
    df = exchange.load_data(pair, tf)
    # df_list[pair] = df.loc[:]
    df_list[pair] = df.loc[start_date:]

print("Data load 100%")
# df_list[oldest_pair]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 14
#      12 df_list = {}
#      13 for pair in pair_list:
# ---> 14     df = exchange.load_data(pair, tf)
#      15     # df_list[pair] = df.loc[:]
#      16     df_list[pair] = df.loc[start_date:]
#
# File d:\Python\Cryptobots\Backtest-Tools-V2\analysis\..\utilities\data_manager.py:142, in ExchangeDataManager.load_data(self, coin, interval, start_date, end_date)
#     140 file_name = f"{file_path}{coin.replace('/', '-').replace(':', '-')}.csv"
#     141 if not os.path.exists(file_name):
# --> 142     raise FileNotFoundError(f"Le fichier {file_name} n'existe pas")
#     144 df = pd.read_csv(file_name, index_col=0)
#     145 df.index = pd.to_datetime(df.index, unit='ms')
#
# FileNotFoundError: Le fichier D:\Python\Cryptobots\Backtest-Tools-V2\database\exchanges\binance/1h/ET-USDT-USDT.csv n'existe pas

# %% [markdown]
# <h2>Matrice de correlation</h2>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

close_prices_list = []
volatility_dict = {}

for crypto, df in df_list.items():
    crypto_name = crypto.split('/')[0]
    
    if (df.index <= start_date).any():
        close_prices_list.append(df['close'].rename(crypto_name))
        returns = df['close'].pct_change().dropna()
        volatility = returns.std()
        volatility_dict[crypto_name] = volatility
        
close_prices = pd.concat(close_prices_list, axis=1)
print(f"Nombre de crypto: {len(close_prices_list)}")

# Calcul de la matrice de corrélation
correlation_matrix = close_prices.corr()

average_correlation = correlation_matrix.mean().mean()
print(f"Corrélation moyenne entre toutes les cryptos : {average_correlation}")
sorted_correlation = correlation_matrix.mean().sort_values()
seuil_faible, seuil_forte = 0.7, 0.8
cryptos_faibles_correlations = sorted_correlation[sorted_correlation < seuil_faible]
cryptos_fortes_correlations = sorted_correlation[sorted_correlation > seuil_forte]

print(f"Cryptos avec des corrélations moyennes < à {seuil_faible}:")
print(correlation_matrix[cryptos_faibles_correlations.index].mean())
print(f"Cryptos avec des corrélations moyennes > à {seuil_forte}:")
print(correlation_matrix[cryptos_fortes_correlations.index].mean())

# Affichez la matrice de corrélation avec seaborn
plt.figure(figsize=(15, 10))
# mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidth=.5, 
            annot_kws={'size': 'x-small', 'alpha': 0.8})
plt.title('Matrice de Corrélation')
plt.show()
# Out:
# Nombre de crypto: 25
# Corrélation moyenne entre toutes les cryptos : 0.767280980517066
# Cryptos avec des corrélations moyennes < à 0.7:
# TRX     0.496360
# BNB     0.650846
# ATOM    0.680201
# ETC     0.684004
# ETH     0.684836
# dtype: float64
# Cryptos avec des corrélations moyennes > à 0.8:
# DASH     0.803252
# XMR      0.804940
# LINK     0.808617
# NEO      0.809254
# XLM      0.814176
# THETA    0.815596
# LTC      0.823649
# IOST     0.824615
# IOTA     0.846611
# VET      0.851454
# QTUM     0.853767
# dtype: float64

# %%
sorted_correlation['TRX']  # Pour analyse unique
# Out:
# 0.5133196978497442

# %% [markdown]
# <h2>Volatilité par crypto</h2>

# %%
volatility_df = pd.DataFrame(list(volatility_dict.items()), columns=['Crypto', 'Volatility'])
sorted_volatility_df = volatility_df.sort_values(by='Volatility', ascending=False)

print(f"Nombre de crypto: {len(volatility_df)}")

# Visualisation de l'écart de volatilité
plt.figure(figsize=(10, 6))
sns.barplot(x='Volatility', y='Crypto', data=sorted_volatility_df, palette='viridis', hue='Crypto', dodge=False)
plt.title('Volatilité des Cryptomonnaies')
plt.xlabel('Volatilité')
plt.ylabel('Cryptomonnaie')
plt.show()

# # Afficher les cryptos les plus volatiles
# print("Cryptos avec la plus grande volatilité :")
# print(sorted_volatility_df)
# Out:
# Nombre de crypto: 25

# %%
import matplotlib.pyplot as plt
import numpy as np

# Cryptos à comparer
cryptos_selected = ['BTC/USDT:USDT', 'ATOM/USDT:USDT', 'THETA/USDT:USDT']
volatility_over_time = {crypto: [] for crypto in cryptos_selected}

# Taille de la fenêtre glissante pour le calcul de la volatilité
window_size = 60

plt.figure(figsize=(12, 8))

for crypto in cryptos_selected:
    df_selected = df_list[crypto]
    df_selected = df_selected[df_selected.index >= start_date]

    close_prices = df_selected['close'].values
    returns = np.diff(close_prices) / close_prices[:-1]
    volatilities = np.std(np.lib.stride_tricks.sliding_window_view(returns, window_size), axis=1) * 100
    volatility_over_time[crypto] = volatilities.tolist()

    min_length = min(len(volatility_over_time[crypto]), len(df_selected))
    common_index = df_selected.index[:min_length]

    alpha_value = 1 if 'BTC' in crypto else 0.4
    plt.plot(common_index, volatility_over_time[crypto][:min_length], label=f'Volatilité de {crypto}', alpha=alpha_value)

plt.xlabel('Date')
plt.ylabel('Volatilité (%)')
plt.title(f'Volatilité de {", ".join(c.split("/")[0] for c in cryptos_selected)} dans le temps (à partir du {start_date})')
plt.legend()
plt.show()

# %%
import plotly.graph_objects as go
import plotly.express as px

# Préparation des données
correlation_matrix = close_prices.corr()
volatility_df = pd.DataFrame(list(volatility_dict.items()), columns=['Crypto', 'Volatility'])

# Création de la figure 3D
fig = go.Figure(data=[go.Scatter3d(
    x=volatility_df['Volatility'],
    y=list(correlation_matrix.index),
    z=list(correlation_matrix.mean()),
    text=volatility_df['Crypto'],
    mode='markers',
    marker=dict(
        size=10,
        color=volatility_df['Volatility'],
        opacity=0.8
    )
)])

# Personnalisation du graphique
fig.update_layout(
    height=700,
    title='Corrélation et Volatilité des Crypto-monnaies',
    scene=dict(
        xaxis_title='Volatilité',
        yaxis_title='Crypto-monnaie',
        zaxis_title='Corrélation moyenne'
    ),
    showlegend=False,
    hovermode='closest'
)

# Affichage du graphique
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 5
#       2 import plotly.express as px
#       4 # Préparation des données
# ----> 5 correlation_matrix = close_prices.corr()
#       6 volatility_df = pd.DataFrame(list(volatility_dict.items()), columns=['Crypto', 'Volatility'])
#       8 # Création de la figure 3D
#
# AttributeError: 'numpy.ndarray' object has no attribute 'corr'

# %% [markdown]
# Comparaison

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cryptos à comparer
cryptos_selected = ['BTC/USDT:USDT', 'TRX/USDT:USDT']
normalized_close_prices_list = {}

for crypto in cryptos_selected:
    df_selected = df_list[crypto]
    close_prices = df_selected['close']
    normalized_close_prices = close_prices / close_prices.iloc[0]
    normalized_close_prices_list[crypto] = normalized_close_prices

plt.figure(figsize=(12, 8))

for crypto, normalized_close_prices in normalized_close_prices_list.items():
    plt.plot(df_list[crypto].index, normalized_close_prices, label=crypto)

plt.xlabel('Date')
plt.ylabel('Prix de clôture normalisé')
plt.title(f'Comparaison des prix de clôture normalisés de {cryptos_selected[0].split('/')[0]} et {cryptos_selected[1].split('/')[0]}')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cryptos à comparer
cryptos_selected = ['BTC/USDT:USDT', 'TRX/USDT:USDT']
normalized_close_prices_list = {}

for crypto in cryptos_selected:
    df_selected = df_list[crypto]
    close_prices = df_selected['close']
    min_price = close_prices.min()
    max_price = close_prices.max()
    normalized_close_prices = (close_prices - min_price) / (max_price - min_price)
    normalized_close_prices_list[crypto] = normalized_close_prices

plt.figure(figsize=(12, 8))

for crypto, normalized_close_prices in normalized_close_prices_list.items():
    plt.plot(df_list[crypto].index, normalized_close_prices, label=crypto)

plt.xlabel('Date')
plt.ylabel('Prix de clôture normalisé (min-max)')
plt.title(f'Comparaison des prix de clôture normalisés (min-max) de {cryptos_selected[0].split("/")[0]} et {cryptos_selected[1].split("/")[0]}')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Définition des modèles
def exponential_model(x, a, b):
    return a * np.exp(-b * x)

def logarithmic_model(x, a, b):
    return a * np.log(x) + b

def polynomial_model(x, a, b, c):
    return a * x**2 + b * x + c

# Données
x = np.array([1, 2, 3])
y = np.array([51588, 12336, 1978])

# Définir les valeurs de y pour les années 4 à 10
# Option 1 (recommandée) :
y = np.append(y, [1000 / (i - 3) for i in range(4, 11)])

# Option 2 (non recommandée) :
# y = np.append(y, np.repeat(y[-1], 7))

# Estimation et affichage pour chaque modèle
for model, label in zip([exponential_model, logarithmic_model, polynomial_model], ['Modèle exponentiel', 'Modèle logarithmique', 'Modèle polynomial']):
    try:
        params, _ = curve_fit(model, x, y)
    except ValueError as e:
        print(f"Erreur pour {label} : {e}")
        continue
    
    # Estimation pour chaque année
    y_pred = [model(i, *params) for i in range(1, 11)]
    
    # Affichage du graphique
    plt.plot(x, y, 'o', label='Données')
    plt.plot(x, y_pred, label=label)

# Affichage de la légende
plt.legend()

plt.title('Comparaison des modèles pour les bull runs de Bitcoin')
plt.xlabel('Numéro du bull run')
plt.ylabel('Augmentation en pourcentage')
plt.grid(True)
plt.show()

# Affichage des estimations
for i in range(1, 11):
    print(f"Année {i}:")
    for model, label in zip([exponential_model, logarithmic_model, polynomial_model], ['Modèle exponentiel', 'Modèle logarithmique', 'Modèle polynomial']):
        try:
            params, _ = curve_fit(model, x, y)
        except ValueError:
            print(f"  {label} : Erreur d'ajustement")
            continue
        y_pred = model(i, *params)
        print(f"  {label}: {round(y_pred, 2)}%")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Erreur pour Modèle exponentiel : operands could not be broadcast together with shapes (3,) (10,)
# Erreur pour Modèle logarithmique : operands could not be broadcast together with shapes (3,) (10,)
# Erreur pour Modèle polynomial : operands could not be broadcast together with shapes (3,) (10,)
# Année 1:
#   Modèle exponentiel : Erreur d'ajustement
#   Modèle logarithmique : Erreur d'ajustement
#   Modèle polynomial : Erreur d'ajustement
# Année 2:
#   Modèle exponentiel : Erreur d'ajustement
#   Modèle logarithmique : Erreur d'ajustement
#   Modèle polynomial : Erreur d'ajustement
# Année 3:
#   Modèle exponentiel : Erreur d'ajustement
#   Modèle logarithmique : Erreur d'ajustement
#   Modèle polynomial : Erreur d'ajustement
# Année 4:
#   Modèle exponentiel : Erreur d'ajustement
#   Modèle logarithmique : Erreur d'ajustement
#   Modèle polynomial : Erreur d'ajustement
# Année 5:
#   Modèle exponentiel : Erreur d'ajustement
#   Modèle logarithmique : Erreur d'ajustement
#   Modèle polynomial : Erreur d'ajustement
# Année 6:
#   Modèle exponentiel : Erreur d'ajustement
#   Modèle logarithmique : Erreur d'ajustement
#   Modèle polynomial : Erreur d'ajustement
# Année 7:
#   Modèle exponentiel : Erreur d'ajustement
#   Modèle logarithmique : Erreur d'ajustement
#   Modèle polynomial : Erreur d'ajustement
# Année 8:
#   Modèle exponentiel : Erreur d'ajustement
#   Modèle logarithmique : Erreur d'ajustement
#   Modèle polynomial : Erreur d'ajustement
# Année 9:
#   Modèle exponentiel : Erreur d'ajustement
#   Modèle logarithmique : Erreur d'ajustement
#   Modèle polynomial : Erreur d'ajustement
# Année 10:
#   Modèle exponentiel : Erreur d'ajustement
#   Modèle logarithmique : Erreur d'ajustement
#   Modèle polynomial : Erreur d'ajustement
